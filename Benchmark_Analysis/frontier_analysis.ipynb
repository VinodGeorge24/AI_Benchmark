# %% [markdown]
# # Which AI is the best at (Frontier)Math?
#
# ## Course: Data Visualization
# ## Professor: Dr. Tweneboah
# ## Author: Vinod George

# %% [markdown]
# The goal of this notebook is to explore which AI models perform best on two of the most rigorous AI math benchmarks:
# - `FrontierMath-2025-02-28-Public`
# - `FrontierMath-2025-02-28-Private`
#
# We rank top models based on average performance across both and visualize the results using best practices in data visualization.

# %% [markdown]
# Before any analysis, we must be aware of WHO we are speaking to.
#
# The usage of AI can be tailored to a specific niche, but in reality anyone can benefit from using AI.
#
# For people that may need it for mathmatical help, may it be accountants, teachers, or students
#
# However, **we will tailor this "story" to the general public!**

# %% [markdown]
# While we are aware of who we are speaking to, why is this analysis important? Why not just stick to the MATH Level 5 analysis Will has done?

# %% [markdown]
# While Math Level 5 comprises challenging **high school** competition problems, FrontierMath features hundreds of unpublished, expert-crafted problems that span advanced fields like algebraic geometry, number theory, and category theory.
#
# Moreover, FrontierMath is designed to minimize data contamination by using entirely new problems, whereas Math Level 5 may include questions similar to those found in AI training datasets.
#
# This makes FrontierMath a more rigorous benchmark for assessing the true limits of AI's mathematical reasoning capabilities, building upon MATH level 5's conclusions and possibly providing further and more detailed insights.

# %% [markdown]
# Now that the jargon and reasoning is done,
#
# ### let's start by importing the necessary libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")  # set the style to whitegrid for better visibility
plt.rcParams['axes.spines.top'] = False  # remove top border
plt.rcParams['axes.spines.right'] = False  # remove right border
plt.rcParams['axes.grid'] = False  # remove gridlines unless we decide to turn them on

# %% [markdown]
# what is the bottom portion of the code? What does it do?
#
# well, based on our guideline on how not to declutter our visualizations and some research, these additions will prove beneficial based on what we have been taught in class!

# %% [markdown]
# ### Load Cleaned Dataset
#
# We use the `master.csv` created during the preprocessing step. It contains all benchmark results merged with metadata like model name, organization, release date, and country.

# %%
df = pd.read_csv("../data/master.csv")

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (326, 6)
#           Model Name Version Release Date     Benchmark  Benchmark Score  \
# 0           Claude 2           2023-07-11  GPQA diamond         0.346591
# 1           Claude 2           2023-07-11  MATH level 5         0.117258
# 2         Claude 2.1           2023-11-21  GPQA diamond         0.329545
# 3  Claude 3.5 Sonnet           2024-06-20  GPQA diamond         0.540404
# 4  Claude 3.5 Sonnet           2024-06-20  MATH level 5         0.516805
#
#   Organization                   Country
# 0    Anthropic  United States of America
# 1    Anthropic  United States of America
# 2    Anthropic  United States of America
# 3    Anthropic  United States of America
# 4    Anthropic  United States of America

# %% [markdown]
# we have loaded it, so next would be to
#
# ### Filter to Relevant Math Benchmarks
#
# We're focusing on the **FrontierMath** aspect of benchmarks. These were chosen for their difficulty and real-world application in high-level math evaluation.

# %% [markdown]
# So, let's filter the data and ensure it includes only what we need

# %%
frontier_df = df[
    df["Benchmark"].isin([
        "FrontierMath-2025-02-28-Public",
        "FrontierMath-2025-02-28-Private"
    ])
]

print("Filtered benchmark entries:", len(frontier_df))
frontier_df.head()

frontier_df
# Out:
# Filtered benchmark entries: 60
#             Model Name Version Release Date                        Benchmark  \
# 185            o3-mini           2025-01-31   FrontierMath-2025-02-28-Public
# 186            o3-mini           2025-01-31  FrontierMath-2025-02-28-Private
# 187             Grok-2           2024-12-12   FrontierMath-2025-02-28-Public
# 188             Grok-2           2024-12-12  FrontierMath-2025-02-28-Private
# 189            o3-mini           2025-01-31   FrontierMath-2025-02-28-Public
# 190            o3-mini           2025-01-31  FrontierMath-2025-02-28-Private
# 191    Mistral Large 2           2024-11-18   FrontierMath-2025-02-28-Public
# 192    Mistral Large 2           2024-11-18  FrontierMath-2025-02-28-Private
# 193             GPT-4o           2024-11-20   FrontierMath-2025-02-28-Public
# 194             GPT-4o           2024-11-20  FrontierMath-2025-02-28-Private
# 195  Claude 3.7 Sonnet           2025-02-24  FrontierMath-2025-02-28-Private
# 196  Claude 3.7 Sonnet           2025-02-24   FrontierMath-2025-02-28-Public
# 197  Claude 3.7 Sonnet           2025-02-24  FrontierMath-2025-02-28-Private
# 200            o1-mini           2024-09-12   FrontierMath-2025-02-28-Public
# 201            o1-mini           2024-09-12  FrontierMath-2025-02-28-Private
# 202            o1-mini           2024-09-12  FrontierMath-2025-02-28-Private
# 203  Claude 3.5 Sonnet           2024-10-22   FrontierMath-2025-02-28-Public
# 204  Claude 3.5 Sonnet           2024-10-22  FrontierMath-2025-02-28-Private
# 205   Gemini 1.5 Flash           2024-09-24   FrontierMath-2025-02-28-Public
# 206   Gemini 1.5 Flash           2024-09-24  FrontierMath-2025-02-28-Private
# 207   Claude 3.5 Haiku           2024-10-22   FrontierMath-2025-02-28-Public
# 208   Claude 3.5 Haiku           2024-10-22  FrontierMath-2025-02-28-Private
# 209  Claude 3.5 Sonnet           2024-06-20   FrontierMath-2025-02-28-Public
# 210  Claude 3.5 Sonnet           2024-06-20  FrontierMath-2025-02-28-Private
# 211             GPT-4o           2024-08-06   FrontierMath-2025-02-28-Public
# 212             GPT-4o           2024-08-06  FrontierMath-2025-02-28-Private
# 213   Gemini 2.0 Flash           2025-02-05   FrontierMath-2025-02-28-Public
# 214   Gemini 2.0 Flash           2025-02-05  FrontierMath-2025-02-28-Private
# 215                 o1           2024-12-17   FrontierMath-2025-02-28-Public
# 216                 o1           2024-12-17  FrontierMath-2025-02-28-Private
# 217     Gemini 2.0 Pro           2025-02-05   FrontierMath-2025-02-28-Public
# 226        DeepSeek-V3           2024-12-26   FrontierMath-2025-02-28-Public
# 227        DeepSeek-V3           2024-12-26  FrontierMath-2025-02-28-Private
# 237  Claude 3.7 Sonnet           2025-02-24  FrontierMath-2025-02-28-Private
# 255        Qwen2.5-Max           2025-01-25   FrontierMath-2025-02-28-Public
# 256        Qwen2.5-Max           2025-01-25  FrontierMath-2025-02-28-Private
# 268      Llama 4 Scout           2025-04-05   FrontierMath-2025-02-28-Public
# 269      Llama 4 Scout           2025-04-05  FrontierMath-2025-02-28-Private
# 272   Llama 4 Maverick           2025-04-05   FrontierMath-2025-02-28-Public
# 273   Llama 4 Maverick           2025-04-05  FrontierMath-2025-02-28-Private
# 276             Grok-3           2025-04-09   FrontierMath-2025-02-28-Public
# 278             Grok-3           2025-04-09  FrontierMath-2025-02-28-Private
# 282        Grok-3 mini           2025-04-09   FrontierMath-2025-02-28-Public
# 283        Grok-3 mini           2025-04-09  FrontierMath-2025-02-28-Private
# 287        Grok-3 mini           2025-04-09  FrontierMath-2025-02-28-Private
# 292            GPT-4.1           2025-04-14   FrontierMath-2025-02-28-Public
# 293            GPT-4.1           2025-04-14  FrontierMath-2025-02-28-Private
# 297       GPT-4.1 mini           2025-04-14   FrontierMath-2025-02-28-Public
# 298       GPT-4.1 mini           2025-04-14  FrontierMath-2025-02-28-Private
# 302       GPT-4.1 nano           2025-04-14   FrontierMath-2025-02-28-Public
# 303       GPT-4.1 nano           2025-04-14  FrontierMath-2025-02-28-Private
# 306                 o3           2025-04-16   FrontierMath-2025-02-28-Public
# 307                 o3           2025-04-16  FrontierMath-2025-02-28-Private
# 310            o4-mini           2025-04-16   FrontierMath-2025-02-28-Public
# 311            o4-mini           2025-04-16  FrontierMath-2025-02-28-Private
# 317                 o3           2025-04-16   FrontierMath-2025-02-28-Public
# 318                 o3           2025-04-16  FrontierMath-2025-02-28-Private
# 319            o4-mini           2025-04-16   FrontierMath-2025-02-28-Public
# 320            o4-mini           2025-04-16  FrontierMath-2025-02-28-Private
# 321            o4-mini           2025-04-16  FrontierMath-2025-02-28-Private
#
#      Benchmark Score Organization                   Country
# 185         0.400000       OpenAI  United States of America
# 186         0.110345       OpenAI  United States of America
# 187         0.000000          xAI  United States of America
# 188         0.006897          xAI  United States of America
# 189         0.112500       OpenAI  United States of America
# 190         0.080819       OpenAI  United States of America
# 191         0.000000   Mistral AI                    France
# 192         0.003448   Mistral AI                    France
# 193         0.000000       OpenAI  United States of America
# 194         0.003448       OpenAI  United States of America
# 195         0.031034    Anthropic  United States of America
# 196         0.000000    Anthropic  United States of America
# 197         0.041379    Anthropic  United States of America
# 200         0.000000       OpenAI  United States of America
# 201         0.013793       OpenAI  United States of America
# 202         0.017241       OpenAI  United States of America
# 203         0.000000    Anthropic  United States of America
# 204         0.020690    Anthropic  United States of America
# 205         0.000000       Google  United States of America
# 206         0.000000       Google  United States of America
# 207         0.000000    Anthropic  United States of America
# 208         0.003448    Anthropic  United States of America
# 209         0.000000    Anthropic  United States of America
# 210         0.010345    Anthropic  United States of America
# 211         0.000000       OpenAI  United States of America
# 212         0.003448       OpenAI  United States of America
# 213         0.000000       Google  United States of America
# 214         0.017241       Google  United States of America
# 215         0.000000       OpenAI  United States of America
# 216         0.093103       OpenAI  United States of America
# 217         0.000000       Google  United States of America
# 226         0.000000     DeepSeek                     China
# 227         0.017241     DeepSeek                     China
# 237         0.034483    Anthropic  United States of America
# 255         0.000000      Alibaba                     China
# 256         0.010345      Alibaba                     China
# 268         0.000000      Meta AI  United States of America
# 269         0.000000      Meta AI  United States of America
# 272         0.000000      Meta AI  United States of America
# 273         0.006897      Meta AI  United States of America
# 276         0.000000          xAI  United States of America
# 278         0.037931          xAI  United States of America
# 282         0.000000          xAI  United States of America
# 283         0.058621          xAI  United States of America
# 287         0.027586          xAI  United States of America
# 292         0.000000       OpenAI  United States of America
# 293         0.055172       OpenAI  United States of America
# 297         0.100000       OpenAI  United States of America
# 298         0.044828       OpenAI  United States of America
# 302         0.000000       OpenAI  United States of America
# 303         0.010345       OpenAI  United States of America
# 306         0.100000       OpenAI  United States of America
# 307         0.103448       OpenAI  United States of America
# 310         0.300000       OpenAI  United States of America
# 311         0.172414       OpenAI  United States of America
# 317         0.000000       OpenAI  United States of America
# 318         0.100000       OpenAI  United States of America
# 319         0.200000       OpenAI  United States of America
# 320         0.193103       OpenAI  United States of America
# 321         0.096552       OpenAI  United States of America

# %% [markdown]
# Now, to calculate the BEST, we of course would need the **highest score** on average, it makes sense.
#
# More specifically,
#
# ## Compute Average Score Per Model
#
# We group by each model and its organization, then calculate the **mean score** across both FrontierMath benchmarks. This lets us rank models based on overall math performance.
#
# so let's group by model and organization to calculate the average benchmark score

# %%
top_models = (
    frontier_df
    .groupby(["Model Name", "Organization"])["Benchmark Score"]
    .mean()
    .reset_index()
    .sort_values(by="Benchmark Score", ascending=False)
)

top_models.head()
# Out:
#       Model Name Organization  Benchmark Score
# 22       o4-mini       OpenAI         0.192414
# 21       o3-mini       OpenAI         0.175916
# 20            o3       OpenAI         0.075862
# 5   GPT-4.1 mini       OpenAI         0.072414
# 18            o1       OpenAI         0.046552

# %% [markdown]
# So, these are the top 10 scoring AI's
#
# It's interesting to note how Open AI's are leading this, but here's the question,
#
# ## **what would classify as a good score?**

# %%
frontier_df["Benchmark Score"].describe(percentiles=[.25, .5, .75, .9])
# Out:
# count    60.000000
# mean      0.043969
# std       0.076757
# min       0.000000
# 25%       0.000000
# 50%       0.008621
# 75%       0.056034
# 90%       0.110560
# max       0.400000
# Name: Benchmark Score, dtype: float64

# %% [markdown]
# So, based on this:
#
# We define score tiers based on percentile rankings across all entries:
# - **Exceptional**: Top 10% (> 0.11)
# - **Strong**: Top 25% (> 0.07)
# - **Average**: around 0.03
# - **Weak**: < 0.01
#
# Very few models score above 0.1, showing how difficult these tasks are.

# %% [markdown]
# So, we have done our numerical steps such as filtering our dataset and classifying our goal of what is our score thresholds.
#
# Now it's time to visualize which AI is the best at math. Let's start by analyzing which country could be the best. Now, we know countries developing AI's are limited, so we have an idea it could be skewed, but it could still be beneficial.

# %%
country_avg = (
    frontier_df
    .groupby("Country")["Benchmark Score"]
    .mean()
    .sort_values(ascending=False)
    .reset_index()
)

plt.figure(figsize=(10, 5))
sns.barplot(data=country_avg.head(7), x="Benchmark Score", y="Country", palette="dark")

plt.title("Top Countries by Avg FrontierMath Score", fontsize=14)
plt.xlabel("Average Score", fontsize=12)
plt.ylabel("Country", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\vgeor\AppData\Local\Temp\ipykernel_19060\689282467.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# So again, here we can limit our analysis for "best" AI to US models
#
# Hence, a model like DeepSeek may not be the best model for Math (although it could be the best at something else). So as we expected in terms of the skew

# %% [markdown]
# along with countries, we can do a boxplot to see it through the scope of organization

# %%
from plotnine import ggplot, aes, geom_boxplot, coord_flip, labs

ggplot(frontier_df) + \
    aes(x='Organization', y='Benchmark Score', fill='Organization') + \
    geom_boxplot() + \
    coord_flip() + \
    labs(
        title='Distribution of FrontierMath Scores by Organization',
        x='Organization',
        y='Benchmark Score'
    )

# %% [markdown]
# A boxplot shows the spread of scores per organization, so along with countries can show a complete picture on if a country like the US have "the best AI models" based on Frontiermath

# %% [markdown]
# More conclusively, this plot reveals that consistency and volume both matter when judging AI model performance. While OpenAI leads with both high peaks and breadth, xAI holds steady in the strong tier.
#
# Google’s limited presence here may not do justice to their actual breakthroughs, which might show more clearly on other benchmarks or in future releases.
#
# Overall, this plot complements the country bar chart by showing not just who’s best, but how reliably they perform across math-focused evaluations.

# %% [markdown]
# We could also do a histogram for score distrubution, which shows how rare high scores really are, backing up our "exceptional/strong/weak" categories

# %%
plt.figure(figsize=(9, 5))
sns.histplot(frontier_df["Benchmark Score"], bins=30, kde=True)

plt.axvline(0.11, color='green', linestyle='--', label='Exceptional Threshold')
plt.axvline(0.07, color='orange', linestyle='--', label='Strong Threshold')
plt.axvline(0.01, color='red', linestyle='--', label='Weak Threshold')

#to remove previous white space from professor's remark
plt.xlim(left=0)  

plt.title("Distribution of AI Scores on FrontierMath Benchmarks", fontsize=14)
plt.xlabel("Benchmark Score")
plt.ylabel("Frequency")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# I chose these colors because it's easier to pre-attentively associate:
#
# **A. Red to low/bad performance (Weak)**
#
# **B. Orange to moderate but not outstanding (Strong)**
#
# **C. Green to excellent performance (Exceptional or "go")**
#
#
# However, analyzing it further...
#
# - Most AI models fall below the 0.01 "Weak" threshold, this indicates that the vast majority of models struggle with FrontierMath, validating the benchmark’s difficulty.
#
# - The distribution is right-skewed, meaning only a few "exceptional" models achieve strong or exceptional scores.
#
# - The Exceptional threshold (> 0.11) is rarely crossed, and only by a select group of top-tier models like GPT-4 and Claude 3 Opus.
#
# - The Strong tier (0.07–0.11) has only a handful of entries, indicating that "good" performance is already a high bar.
#
# - This histogram justifies why average score alone isn't enough, context matters, and percentile tiers help us better interpret what “best” actually means.
#
# By visualizing the distribution and thresholds clearly, we give the general audience a way to understand just how hard it is for AI models to do well on these math benchmarks.

# %% [markdown]
# With all of these out of the way, now we need to:
#
# ## Visualize Top 10 AI Models

# %%
plt.figure(figsize=(8, 6))
top10 = top_models.head(10)

barplot = sns.barplot(
    data=top10,
    y="Model Name",
    x="Benchmark Score",
    hue="Organization",
    dodge=False,
    palette="deep"
)

# Styling: remove clutter
barplot.legend().remove()  # remove legend for cleaner layout
barplot.set_xlabel("Avg Score on FrontierMath", fontsize=12)
barplot.set_ylabel("AI Model", fontsize=12)
plt.title("Top 10 AI Models on FrontierMath Benchmarks", fontsize=14)
sns.despine()  # remove top/right borders
plt.tight_layout()

plt.show()

# %% [markdown]
# This horizontal bar chart shows the top 10 AI models based on their average performance on the FrontierMath benchmarks. It follows best data viz practices by:
# - Removing borders and gridlines
# - Avoiding legends in favor of direct labeling
# - Using a consistent color scheme
# - Simplifying axes and labels
#
# Now, concluding on this graph:
#
# - Although many models are well known, only a few surpass the benchmark thresholds that qualify as strong or exceptional performance.
#
# - The top three models (o4-mini, o3-mini, and o3) stand out significantly, each exceeding the 0.11 Exceptional threshold by a clear margin.
#
# - Claude 3.7 Sonnet, colored in green, demonstrates solid performance and represents one of the few non-OpenAI models to approach or pass the Exceptional mark.
#
# - Grok-3 mini and Grok-3 fall into the Strong category, showing that xAI models have potential but still lag behind the top performers.
#
# - Most other models, including GPT-4.1 and o1, fall below the Exceptional threshold, and some even below the Strong threshold, showcasing the difficulty of FrontierMath.
#
# In essence, this ranking provides direct evidence of performance gaps between leading AI developers and helps identify which models consistently excel at complex mathematical reasoning.

# %% [markdown]
# so now we have some visualizations, let's export this new dataframe to be usable in other scenarios

# %%
frontier_df.to_csv("frontier_math_filtered.csv", index=False)
